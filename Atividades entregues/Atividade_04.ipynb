# %% [markdown]
# Centro de Educação Tecnologia do Amazonas - IBC
#
# Manaus, 24 de março de 2026
#
# Aluno: Felipe Nunes Briglia

# %%
nu1, nu2 = 0, 0
print('Olá, mundo!!')

print(5 + 5 - 2)
print(nu1)
print(5**2)
print(nu2)
# Out:
# Olá, mundo!!
# 8
# 0
# 25
# 0

# %%
def dobro(x):
    print(x * 2)

dobro(125)
# Out:
# 250

# %%
print("Curso técnico em nível médio de inteligência artificial - Turma2026.1")
# Out:
# Curso técnico em nível médio de inteligência artificial - Turma2026.1
